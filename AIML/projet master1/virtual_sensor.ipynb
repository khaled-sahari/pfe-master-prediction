# %%
import pandas as pd
import joblib
import json
from tensorflow.keras.models import load_model

# %%
# LOAD CONFIG
with open("models/config.json") as f:
    config = json.load(f)

features = config["features"]
targets = config["targets"]

# %%
# LOAD DATA
df = pd.read_csv("FINAL_DATASET_PREDICTION_CEjour.csv")

# %%
# SIMULER PANNE
df_virtual = df.copy()

df_virtual["W_GAS_real"] = df_virtual["W_GAS"]
df_virtual["WATER_real"] = df_virtual["WATER"]
df_virtual["COND_real"] = df_virtual["COND_VOL"]



X = df_virtual[features]

# %%
# LOAD MODEL (choix)
model = joblib.load("models/LinearRegression.pkl")  # ou LR.pkl

# %%
# PREDICTION
y_pred = model.predict(X)

df_virtual["GAS_pred"] = y_pred[:,0]
df_virtual["WATER_pred"] = y_pred[:,1]
df_virtual["COND_pred"] = y_pred[:,2]

df_virtual.to_csv("results/virtual_sensor.csv", index=False)

print("✅ Virtual sensor done")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # PREDICTION
# ----> 2 y_pred = model.predict(X)
#       3
#       4 df_virtual["GAS_pred"] = y_pred[:,0]
#       5 df_virtual["WATER_pred"] = y_pred[:,1]
#
# File a:\pfe master\PEG_Python-master\.venv\Lib\site-packages\sklearn\pipeline.py:746, in Pipeline.predict(self, X, **params)
#     744     for _, name, transform in self._iter(with_final=False):
#     745         Xt = transform.transform(Xt)
# --> 746     return self.steps[-1][1].predict(Xt, **params)
#     748 # metadata routing enabled
#     749 routed_params = process_routing(self, "predict", **params)
#
# File a:\pfe master\PEG_Python-master\.venv\Lib\site-packages\sklearn\linear_model\_base.py:311, in LinearModel.predict(self, X)
#     297 def predict(self, X):
#     298     """
#     299     Predict using the linear model.
#     300
# ...
